# %%
import pandas as pd
import tabulate

# %% [markdown]
# # Convert CSV to Markdown Table
#     JMA 12 June 2026

# %%
# Load your CSV file
df = pd.read_csv("schedule_table.csv")

# Convert to markdown format
markdown_table = df.to_markdown(index=False)

# Save the table to a markdown file
with open("schedule_table.md", "w", encoding="utf-8") as f:
    f.write(markdown_table)
